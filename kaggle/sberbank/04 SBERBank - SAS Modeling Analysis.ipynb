# %% [markdown]
# ## RMSLE from SAS

# %%
import pandas as pd
import numpy as np

# Statistical Packages
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# import plotting libraries
from statsmodels.graphics.factorplots import interaction_plot
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# style
# %matplotlib inline
plt.style.use('seaborn-white')

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 200, 'display.float_format', lambda x: '%.3f' % x)
sns.set(style='white', context='notebook', palette='deep')

# %%
submission = pd.read_csv("./data/sample_submission.csv")
lasso_result = pd.read_csv("./data/lasso_result.csv")

# %%
lasso_result = lasso_result[lasso_result.id.isin(test.id)]
lasso_result.head()

# %%
submission.head()

# %%
#lasso_result = pd.read_csv("./data/lasso_result (8).csv")
lasso_result = pd.read_csv("./data/elastic_model_output_sbc (5).csv")
lasso_result.head()
# Out:
#    VAR1  index  MonthYear       area_m  bigmarket  build_decade  build_year  \
# 0     0      0     201108  6407578.100          0          1970        1975
# 1     2      2     201108  4808269.831          0          1960        1969
# 2     3      3     201109 12583535.690          0          2010        2015
# 3     6      6     201109 10320473.230          0          1960        1966
# 4     7      7     201109  6407578.100          0          1970        1975
#
#    cafe_count_5000_price_1500  catering_km  culture_top25   districts ecology  \
# 0                          40        0.517              0  north_east    good
# 1                          25        0.190              0  south_east    poor
# 2                          15        0.466              0  north_west    good
# 3                         144        0.447              0        east    poor
# 4                          36        0.374              0  north_east    good
#
#    full_sq  id  kremlin_km  life_sq  male_female_rate  market_count_5000  \
# 0       43   1      15.156   27.000             0.885                  4
# 1       43   3       9.068   29.000             0.824                 10
# 2       89   4      19.487   50.000             0.868                  3
# 3       25   7       6.469   14.000             0.900                  8
# 4       44   8      15.770   44.000             0.885                  4
#
#    metro_min_avto  num_room  price_doc  product_type_investment  raion_popul  \
# 0          -0.362         2    5850000                        1       155572
# 1          -0.433         2    5700000                        1       101708
# 2          -0.530         3   13100000                        1       178473
# 3          -0.535         2    5500000                        1        57405
# 4          -0.205         2    2000000                        1       155572
#
#    school_education_centers_raion  school_top20_raison  VAR26  \
# 0                               5                    0      0
# 1                               7                    0      0
# 2                              10                    0      0
# 3                               5                    0      0
# 4                               5                    0      0
#
#    sport_objects_raion state_cat        sub_area  ttk_km  workers_perc  \
# 0                    7      okay        Bibirevo  10.919         1.139
# 1                    5      okay  Tekstil'shhiki   2.927         0.622
# 2                   17      poor          Mitino  14.607         5.690
# 3                   17      okay      Sokol'niki   2.027         0.407
# 4                    7      okay        Bibirevo  11.534         1.139
#
#    workplaces_km  zd_vokzaly_avto_km  full_sq_scale  life_sq_scale  \
# 0          0.884              14.232         -0.476         -0.498
# 1          1.510               9.541         -0.476         -0.401
# 2          0.622              17.478          1.504          0.620
# 3          0.544               3.029         -1.250         -1.130
# 4          1.099              14.434         -0.432          0.328
#
#    zd_vokzaly_scale  raion_popul_scale  kremlin_km_scale  ttk_km_scale  \
# 0            -0.290              1.231            -0.106        -0.050
# 1            -0.745              0.303            -0.827        -1.040
# 2             0.025              1.626             0.407         0.407
# 3            -1.376             -0.461            -1.134        -1.152
# 4            -0.270              1.231            -0.033         0.026
#
#    catering_km_scale  area_m_scale  price_log  full_sq_log  life_sq_log  \
# 0             -0.205        -0.544     15.582        3.784        3.332
# 1             -0.597        -0.622     15.556        3.784        3.401
# 2             -0.266        -0.245     16.388        4.500        3.932
# 3             -0.289        -0.355     15.520        3.258        2.708
# 4             -0.377        -0.544     14.509        3.807        3.807
#
#    catering_km_log  zd_vokzalykm_log    _ROLE_  _CVINDEX_  predict      r
# 0           -0.660             2.723     TRAIN          1   15.513  0.069
# 1           -1.658             2.355     TRAIN          2   15.519  0.037
# 2           -0.764             2.917  VALIDATE          0   16.213  0.175
# 3           -0.805             1.393     TRAIN          3   15.472  0.048
# 4           -0.984             2.737     TRAIN          4   15.524 -1.015

# %%
l_result = lasso_result[lasso_result._ROLE_ == 'VALIDATE'][['price_doc', 'predict']]
l_result['predicted_price'] = np.exp(l_result.predict)
l_result.head()
# Out:
#     price_doc  predict  predicted_price
# 2    13100000   16.213     10992630.163
# 5     5300000   15.546      5645531.250
# 8     5200000   15.498      5381577.539
# 9     1850000   15.721      6720122.577
# 13    6250000   15.662      6334707.439

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, r2_score

print("RMSLE: ", np.sqrt(mean_squared_log_error(abs(l_result.predicted_price),l_result.price_doc)))
# Out:
# RMSLE:  0.47580018792873136

# %%
import math

#A function to calculate Root Mean Squared Logarithmic Error (RMSLE)
def rmsle(y, y_pred):
    assert len(y) == len(y_pred)
    terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
    return print((sum(terms_to_sum) * (1.0/len(y))) ** 0.5)

# %%
assert len(y) == len(y_pred)

# %%
terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-0aecd0ac9011> in <module>
# ----> 1 terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
#
# <ipython-input-75-0aecd0ac9011> in <listcomp>(.0)
# ----> 1 terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
#
# ~\AppData\Local\Continuum\anaconda3\envs\bril\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\AppData\Local\Continuum\anaconda3\envs\bril\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
def rmsle(y_pred, y_test) : 
    assert len(y_test) == len(y_pred)
    return np.sqrt(np.mean((np.log(1+y_pred) - np.log(1+y_test))**2))

# %%
def rmsle(y, y_):
    log1 = np.nan_to_num(np.array([np.log(v + 1) for v in y]))
    log2 = np.nan_to_num(np.array([np.log(v + 1) for v in y_]))
    calc = (log1 - log2) ** 2
    return np.sqrt(np.mean(calc))

# %%
rmsle(l_result.predicted_price, l_result.price_doc)
# Out:
# 0.47580018792873136

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error, r2_score


print("RMSLE: %.3f" % np.sqrt(mean_squared_error(y_test, predictions)))
print ("R^2: %.3f" % r2_score(y_test, predictions))
print("Result: %.3f" % model_lr.score(X_train, y_train))
print("RMSLE: ", np.sqrt(mean_squared_log_error(predictions,y_test)))
print("RMSLE: ", np.sqrt(mean_squared_log_error(predictions,y_test)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-53ab819facc9> in <module>
#       2
#       3
# ----> 4 print("RMSLE: %.3f" % np.sqrt(mean_squared_error(y_test, predictions)))
#       5 print ("R^2: %.3f" % r2_score(y_test, predictions))
#       6 print("Result: %.3f" % model_lr.score(X_train, y_train))
#
# NameError: name 'y_test' is not defined
