# %% [markdown]
# # Predicting Food Truck Sales
#
# ![](https://i.ytimg.com/vi/jF8WeA9qvWw/maxresdefault.jpg)
#
#
# Source: [Kaggle: Coursera - Machine LEarning - Andrew_Ng](https://www.kaggle.com/saxenapriyansh/coursera-machine-learning-andrew-ng#week_1-ex_1.txt)
#
#
# __Objective:__ to predict profits for a food truck. Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet. The chain already has trucks in various cities and you have data for profits and populations from the cities.

# %%
import pandas as pd

# Data Visualization
import seaborn as sns
sns.set(style="darkgrid")
import matplotlib.pyplot as plt 
# %matplotlib inline
from matplotlib import style

# Statistical Packages
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# import food truck data
truck = pd.read_table("./food_truck.txt", header=None, sep=',',
                      names=['city_population', 'profits'])
truck.head()
# Out:
#    city_population  profits
# 0           6.1101  17.5920
# 1           5.5277   9.1302
# 2           8.5186  13.6620
# 3           7.0032  11.8540
# 4           5.8598   6.8233

# %% [markdown]
# ## Simple Linear Regression
#
# ### Least Squares Fit
# For the Advertising data, we will plot the least squares fit for the regression of `profits` onto `city_population`.
#
# The simple linear regression formula to indicate this relationship is:
#
# `profits` ≈ $\beta_{0} + \beta_{1} x$ `city_population`
#
# Next we will plot a scatter plot with a regression lint to view the distribution and see if this is a good fit for a regression problem.

# %%
sns.jointplot("city_population", "profits", data=truck, kind="reg",
              color="r", height=7)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# View 2:

# %%
sns.regplot(truck.city_population, truck.profits, order = 1,
           ci = None, scatter_kws={'color':'r', 's':9})

# %% [markdown]
# ### Estimating Regression Coefficient
#
# Now we define a linear regression model with the `profits` column as the response and the `city_population` column as the feature in the `truck` dataset.

# %%
# Ordinary Least Squares (ols) 

#create fitted model
lm = smf.ols(formula='profits ~ city_population', data = truck).fit()

print(lm.params,'\n')
print(lm.summary())
# Out:
# Intercept         -3.895781
# city_population    1.193034
# dtype: float64
#
#                             OLS Regression Results
# ...
# Dep. Variable:                profits   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     223.8
# Date:                Mon, 14 Jan 2019   Prob (F-statistic):           1.02e-26
# Time:                        07:16:53   Log-Likelihood:                -243.95
# No. Observations:                  97   AIC:                             491.9
# Df Residuals:                      95   BIC:                             497.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
