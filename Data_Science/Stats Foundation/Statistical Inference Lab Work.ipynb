# %% [markdown]
# # Lab Work for Basic Statistical Inference
#
# ![](https://i.ytimg.com/vi/YXllcQUAA_s/maxresdefault.jpg)

# %%
import numpy as np
import pandas as pd

# Data Visualization
import seaborn as sns
sns.set(style="darkgrid")
import matplotlib.pyplot as plt 
# %matplotlib inline
from matplotlib import style

# %% [markdown]
# #### Use software to generate 10 observations from a normal distribution with mean, µ = 5 and standard deviation, σ = 12.
#
# We will use the `get_truncated_normal()` function from `scipy` to instance the generator with the parameters: mean, standard deviation, and truncation range:

# %%
from scipy.stats import truncnorm

def get_truncated_normal(mean=0, sd=1, low=0, upp=10):
    # https://stackoverflow.com/questions/36894191/how-to-get-a-normal-distribution-within-a-range-in-numpy
    return truncnorm((low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)


x = get_truncated_normal(mean = 5, sd = 12)

fig = plt.figure(figsize=(15,8))
ax = sns.distplot(x.rvs(10, random_state=0), kde=True)
plt.title("Histogram of normal random numbers")
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# With only to 10 samples, there appears to be somewhat normal. The observations appear to fit the normal density curve, while there are still some minor off setting of the data, it appears to be have more mode of overvations around 5, indicating the middle of the distrbution.

# %%
import statsmodels.api as sm
x = x.rvs(10, random_state=0)
sm.qqplot(x, fit=True, line='45')

# %% [markdown]
# There are some important deviations as it appears to curve away from the linear line.

# %% [markdown]
# #### Use software to generate 100 observations from a normal distribution with mean, µ = 5 and standard deviation, σ = 12.

# %%
x = get_truncated_normal(mean = 5, sd = 12)

fig = plt.figure(figsize=(15,8))
ax = sns.distplot(x.rvs(100, random_state=0), kde=True)
plt.title("Histogram of normal random numbers")
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# With more observations, there appears to be a better fit of normality, which is also justified by the central limit theorem. The plots  A and B are different in that the they are two independent datasets of differe and B has more samples which allows the distribution to fit the normal distribution better.

# %%
x = x.rvs(100, random_state=0)
sm.qqplot(x, fit=True, line='45')

# %% [markdown]
# There are some observations on the tails of the distributions to indicate some deviaions, it is more minor than the deviaions in the first QQ plot. However, the appears to be a good fit for the linear line. I think the QQ plot does not suggest important deviations from normality.

# %% [markdown]
# #### Random numbers from other distributions

# %%
X1 = get_truncated_normal(mean = .5, sd = 3).rvs(100, random_state=0) # right skewed
X2 = get_truncated_normal(mean = 9, sd = 3).rvs(100, random_state=0) # left skewed,
X3 = get_truncated_normal(mean = 5, sd =.5 ).rvs(100, random_state=0) # short tailed 
X4 = get_truncated_normal(mean = 5, sd =8 ).rvs(100, random_state=0) # long tailed 

fig, ax = plt.subplots(4, sharex=True, figsize=(15,8))
sns.distplot(X1, kde=True, ax = ax[0]) # right skewed
sns.distplot(X2, kde=True, ax = ax[1]) # left skewed,
sns.distplot(X3, kde=True, ax = ax[2]) # short tailed 
sns.distplot(X4, kde=True, ax = ax[3]) # long tailed 
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Next we will use the `statsmodel` api to plot a Normal Quantile

# %%
import statsmodels.api as sm
fig, ax = plt.subplots(4, sharex=True, figsize=(15,8))
sm.qqplot(X1, ax=ax[0], fit=True, line='45')
sm.qqplot(X2, ax=ax[1], fit=True, line='45')
sm.qqplot(X3, ax=ax[2], fit=True, line='45')
sm.qqplot(X4, ax=ax[3], fit=True, line='45')

# %% [markdown]
# ## 04 - Central Limit Theorem
#
# #### Objectives: A better understanding of the Central Limit Theorem
#
# [purdue](https://github.com/jordanimayer/STAT350/blob/master/Lab%2004%20-%20Central%20Limit%20Theorem/Lab%2004%20Solution.pdf)

# %%
import numpy as np                      # import data manipulation (create data)
import matplotlib.pyplot as plt         # import data visualization (plot data)

## create nornmal distribtion plot centered around a mean of 90, showing a 
## a 2 standard deviation of the data  and created 10,000 random data points
## that are normally distributied
values= np.random.normal(90,2, 10000)   
plt.hist(values,50)                     # plot 50 bins with the line
plt.show()                              # graph plot

# %% [markdown]
# Simulating the distribution of the mean (X̄) for four different distributions:
# - normal,
# - uniform,
# - gamma and
# - Poisson
#
# __In this lab, you will create 1000 random samples of size n for each of the distributions below. The number of samples that you will be averaging, n depends on the given distribution. For each of the 1000 random samples, compute the sample mean, x̄ . So you will have 1000 x̄ ’s for each given sample size n__
#
# #### Standard Normal Distribution. n = 1, 2, 6 and 10.

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

for k in 

# random samplings
n_1 = np.random.normal(0, 1, 1000)  
n_2 = np.random.normal(90,2, 1000)   
n_6 = np.random.normal(90,2, 1000)   
n_10 = np.random.normal(90,2, 1000)   

# sample mean
n_1_mean = np.mean(n_1)
n_2_mean = np.mean(n_2)
n_6_mean = np.mean(n_6)
n_10_mean = np.mean(n_10)



plt.hist(values,50)                     # plot 50 bins with the line
plt.show()                              # graph plot

# %% [markdown]
# #### Histogram/normal quantile plots
# For each of the values of n, submit a histogram (with the two colored lines) and a normal quantile plot. For each of the graph pairs, indicate whether the situation is normal or not.

# %%
np.random.seed(0)
nperm = 1000

#mu, sigma = 0, 0.1 # mean and standard deviation
#s = np.random.normal(mu, sigma, 1000)
n1_perms = np.zeros(nperm + 1)
n2_perms = np.zeros(nperm + 1)
n6_perms = np.zeros(nperm + 1)
n10_perms = np.zeros(nperm + 1)

# random samplings
for i in range(1, nperm): 
    n1_perms[i] = np.mean(np.random.normal(size = 1))
    n2_perms[i] = np.mean(np.random.normal(size = 2))
    n6_perms[i] = np.mean(np.random.normal(size = 6))
    n10_perms[i] = np.mean(np.random.normal(size = 10))

    
# Plot Distributions
fig = plt.figure()

plt.subplot(2, 2, 1)
plt.title('Hist Norm Dist n = 1')
plt.hist(n1_perms)


plt.subplot(2, 2, 2)
plt.title('Hist Norm Dist n = 2')
plt.hist(n2_perms)




plt.subplot(2, 2, 3)
plt.title('Hist Norm Dist n = 6')
plt.hist(n6_perms)



plt.subplot(2, 2, 4)
plt.title('Hist Norm Dist n = 10')
plt.hist(n10_perms)
# Out:
# (array([  3.,  19.,  35., 138., 228., 268., 200.,  83.,  24.,   3.]),
#  array([-1.12859178, -0.91577055, -0.70294933, -0.49012811, -0.27730688,
#         -0.06448566,  0.14833556,  0.36115679,  0.57397801,  0.78679923,
#          0.99962046]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# appears normal

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)

qqplt_ = [n1_perms, n2_perms, n6_perms, n10_perms]
count = 0
for row in ax:
    for col in row:
        sm.qqplot(qqplt_[count], fit=True, line='45', ax=col)
        count = count + 1

plt.show()

# %% [markdown]
# #### Uniform distribution over the interval (0,3). n = 1, 2, 9 and 16.

# %%
#s = np.random.uniform(-1,0,1000)
np.random.seed(0)
nperm = 1000

#mu, sigma = 0, 0.1 # mean and standard deviation
#s = np.random.normal(mu, sigma, 1000)
n1_perms = np.zeros(nperm + 1)
n2_perms = np.zeros(nperm + 1)
n6_perms = np.zeros(nperm + 1)
n10_perms = np.zeros(nperm + 1)

# random samplings
for i in range(1, nperm): 
    n1_perms[i] = np.mean(np.random.uniform(low = 0, high = 3, size = 1))
    n2_perms[i] = np.mean(np.random.uniform(low = 0, high = 3,size = 2))
    n6_perms[i] = np.mean(np.random.uniform(low = 0, high = 3,size = 9))
    n10_perms[i] = np.mean(np.random.uniform(low = 0, high = 3,size = 16))

    
# Plot Distributions
fig = plt.figure()

plt.subplot(2, 2, 1)
plt.title('Hist uniform Dist n = 1')
plt.hist(n1_perms)

plt.subplot(2, 2, 2)
plt.title('Hist uniform Dist n = 2')
plt.hist(n2_perms)

plt.subplot(2, 2, 3)
plt.title('Hist uniform Dist n = 6')
plt.hist(n6_perms)

plt.subplot(2, 2, 4)
plt.title('Hist uniform Dist n = 10')
plt.hist(n10_perms)

fig, ax = plt.subplots(nrows=2, ncols=2)
qqplt_ = [n1_perms, n2_perms, n6_perms, n10_perms]
count = 0
for row in ax:
    for col in row:
        sm.qqplot(qqplt_[count], fit=True, line='45', ax=col)
        plt.title('Hist Norm Dist n = 10')
        count = count + 1

plt.show()

# %%
#shape, scale = 2., 2.  # mean=4, std=2*sqrt(2)
#s = np.random.gamma(shape, scale, 1000)

np.random.seed(0)
nperm = 1000


n1_perms = np.zeros(nperm + 1)
n2_perms = np.zeros(nperm + 1)
n6_perms = np.zeros(nperm + 1)
n10_perms = np.zeros(nperm + 1)

# random samplings
for i in range(1, nperm): 
    n1_perms[i] = np.mean(np.random.gamma(shape = 2, scale = 1, size = 1))
    n2_perms[i] = np.mean(np.random.gamma(shape = 2, scale = 1,size = 5))
    n6_perms[i] = np.mean(np.random.gamma(shape = 2, scale = 1,size = 10))
    n10_perms[i] = np.mean(np.random.gamma(shape = 2, scale = 1,size = 40))

    
# Plot Distributions
fig = plt.figure()

plt.subplot(2, 2, 1)
plt.title('Hist gamma Dist n = 1')
plt.hist(n1_perms)

plt.subplot(2, 2, 2)
plt.title('Hist gamma Dist n = 2')
plt.hist(n2_perms)

plt.subplot(2, 2, 3)
plt.title('Hist gamma Dist n = 6')
plt.hist(n6_perms)

plt.subplot(2, 2, 4)
plt.title('Hist gamma Dist n = 10')
plt.hist(n10_perms)



fig, ax = plt.subplots(nrows=2, ncols=2)
qqplt_ = [n1_perms, n2_perms, n6_perms, n10_perms]
count = 0
for row in ax:
    for col in row:
        sm.qqplot(qqplt_[count], fit=True, line='45', ax=col)
        plt.title('Hist gamma Dist n = 10')
        count = count + 1

plt.show()

# %% [markdown]
# __Hist:__ with lower sample sizes, the distribution moves from a strong right skew to normalization. __for the lower sample sizes, the histogram deviates from the normal curve__
#
# __QQ PLOT:__ Specifically within the QQ plot we can see the upward curved of observations in comparision to the linear line, viz _concave_. __for the smaller sample sizes the QQ plot suggest important deviaitons fromn normality.__
#
# We can see as sample size increased the observations fit the linear line significantly wekk, until we rach sample size 40 and its appears to be normal.

# %% [markdown]
# #### Poisson distribution with parameter $ \lambda$ = 2.

# %%
#s = np.random.poisson(5, 10000)


np.random.seed(0)
nperm = 1000


n1_perms = np.zeros(nperm + 1)
n2_perms = np.zeros(nperm + 1)
n6_perms = np.zeros(nperm + 1)
n10_perms = np.zeros(nperm + 1)

# random samplings
for i in range(1, nperm): 
    n1_perms[i] = np.mean(np.random.poisson(lam = 2, size = 1))
    n2_perms[i] = np.mean(np.random.poisson(lam = 2, size = 15))
    n6_perms[i] = np.mean(np.random.poisson(lam = 2, size = 50))
    n10_perms[i] = np.mean(np.random.poisson(lam = 2, size = 100))

    
# Plot Distributions
fig = plt.figure()

plt.subplot(2, 2, 1)
plt.title('Hist poisson Dist n = 1')
plt.hist(n1_perms)

plt.subplot(2, 2, 2)
plt.title('Hist poisson Dist n = 2')
plt.hist(n2_perms)

plt.subplot(2, 2, 3)
plt.title('Hist poisson Dist n = 6')
plt.hist(n6_perms)

plt.subplot(2, 2, 4)
plt.title('Hist poisson Dist n = 10')
plt.hist(n10_perms)



fig, ax = plt.subplots(nrows=2, ncols=2)
qqplt_ = [n1_perms, n2_perms, n6_perms, n10_perms]
count = 0
for row in ax:
    for col in row:
        sm.qqplot(qqplt_[count], fit=True, line='45', ax=col)
        plt.title('Hist poisson Dist n = 10')
        count = count + 1

plt.show()

# %%
#s = np.random.exponential(5, 10000)


np.random.seed(0)
nperm = 1000


n1_perms = np.zeros(nperm + 1)
n2_perms = np.zeros(nperm + 1)
n6_perms = np.zeros(nperm + 1)
n10_perms = np.zeros(nperm + 1)

# random samplings
for i in range(1, nperm): 
    n1_perms[i] = np.mean(np.random.exponential(scale = 2, size = 1))
    n2_perms[i] = np.mean(np.random.exponential(scale = 2, size = 15))
    n6_perms[i] = np.mean(np.random.exponential(scale = 2, size = 50))
    n10_perms[i] = np.mean(np.random.exponential(scale = 2, size = 100))

    
# Plot Distributions
fig = plt.figure()

plt.subplot(2, 2, 1)
plt.title('Hist poisson Dist n = 1')
plt.hist(n1_perms)

plt.subplot(2, 2, 2)
plt.title('Hist poisson Dist n = 2')
plt.hist(n2_perms)

plt.subplot(2, 2, 3)
plt.title('Hist poisson Dist n = 6')
plt.hist(n6_perms)

plt.subplot(2, 2, 4)
plt.title('Hist poisson Dist n = 10')
plt.hist(n10_perms)



fig, ax = plt.subplots(nrows=2, ncols=2)
qqplt_ = [n1_perms, n2_perms, n6_perms, n10_perms]
count = 0
for row in ax:
    for col in row:
        sm.qqplot(qqplt_[count], fit=True, line='45', ax=col)
        plt.title('Hist poisson Dist n = 10')
        count = count + 1

plt.show()
